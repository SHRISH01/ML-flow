# %%
import pandas as pd
pd.read_csv("//Users//shrish//Downloads//wine+quality//winequality-white.csv",sep=';')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
from sklearn.model_selection import train_test_split
train , test = train_test_split(pd.read_csv("//Users//shrish//Downloads//wine+quality//winequality-white.csv",sep=';'))

# %%
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2778            7.6              0.39         0.32            3.60      0.035
# 1379            6.9              0.46         0.20            0.90      0.054
# 1504            7.0              0.17         0.74           12.80      0.045
# 3111            6.5              0.23         0.39            1.90      0.036
# 704             5.6              0.25         0.26            3.60      0.037
# ...             ...               ...          ...             ...        ...
# 1259            6.2              0.21         0.38            6.80      0.036
# 3721            7.7              0.30         0.23            2.00      0.068
# 2807            7.5              0.18         0.72            9.60      0.039
# 1782            8.5              0.21         0.26            9.25      0.034
# 40              6.7              0.23         0.39            2.50      0.172
#
# ...

# %%
test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2668            9.6             0.655         0.21            2.00      0.039
# 1727            7.6             0.445         0.44           14.50      0.045
# 2366            7.4             0.330         0.44            7.60      0.050
# 2949            6.0             0.280         0.52            5.00      0.078
# 945             6.7             0.150         0.29            5.00      0.058
# ...             ...               ...          ...             ...        ...
# 2282            7.4             0.330         0.26           15.60      0.049
# 4408            5.7             0.290         0.16            7.90      0.044
# 2631            6.7             0.280         0.28            2.40      0.012
# 1210            9.2             0.280         0.41            1.00      0.042
# 111             7.2             0.270         0.46           18.75      0.052
#
# ...
